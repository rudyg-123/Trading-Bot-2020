# %% [markdown]
# ### Login details

# %%
#Name     : Rudraksh Goel
#Type     : Standard AUD Demo Account
#Server   : GoMarkets-Demo
#Login    : 62986
#Password : xo7rslrx
#Investor : we5sweua

# %% [markdown]
# ## Import modules

# %%
import time
startTime = time.time()

import datetime
from datetime import datetime as dt

import MetaTrader5 as mt5
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mplfinance as mpf
import numba as nb
import smtplib, ssl
import tkinter as tk
from tkinter import ttk
import numba as nb
import pytz

#Uncomment to turn off the warnings for pandas:
pd.options.mode.chained_assignment = None  # default='warn'

from IPython.display import display, HTML

pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', None)
pd.options.display.max_colwidth = 200
pd.options.display.float_format = "{:,.5f}".format

display(HTML("<style>.container { width:80% !important; }</style>"))
print('Importing and set up time = %0.4f' % (time.time() - startTime))
# Out:
# <style>.container { width:80% !important; }</style>
# Importing and set up time = 0.0030

# %%
# %autosave 30
# Out:
# Autosaving every 30 seconds

# %%
h = getData(50, mt5.TIMEFRAME_M1, 'EURUSD')
h
# Out:
#           time    open    high     low   close  tick_volume  spread  \
# 0   1601880600 1.17291 1.17291 1.17286 1.17290           30       1
# 1   1601880660 1.17290 1.17290 1.17289 1.17289           27       1
# 2   1601880720 1.17290 1.17290 1.17280 1.17285           42       1
# 3   1601880780 1.17286 1.17291 1.17282 1.17291           59       1
# 4   1601880840 1.17290 1.17293 1.17285 1.17290           54       1
# 5   1601880900 1.17289 1.17296 1.17284 1.17295           41       1
# 6   1601880960 1.17294 1.17297 1.17294 1.17296           23       1
# 7   1601881020 1.17298 1.17299 1.17278 1.17280           45       1
# 8   1601881080 1.17278 1.17286 1.17272 1.17279           71       1
# 9   1601881140 1.17282 1.17286 1.17278 1.17282           52       1
# 10  1601881200 1.17283 1.17283 1.17267 1.17267           43       1
# 11  1601881260 1.17267 1.17274 1.17267 1.17269           23       1
# 12  1601881320 1.17270 1.17275 1.17269 1.17274           25       1
# 13  1601881380 1.17275 1.17290 1.17275 1.17284           36       1
# 14  1601881440 1.17283 1.17289 1.17283 1.17289           13       1
# 15  1601881500 1.17288 1.17291 1.17287 1.17290           33       1
# 16  1601881560 1.17288 1.17294 1.17288 1.17290           40       1
# 17  1601881620 1.17294 1.17294 1.17289 1.17290           25       1
# 18  1601881680 1.17291 1.17294 1.17289 1.17294           14       1
# 19  1601881740 1.17293 1.17294 1.17282 1.17282           34       1
# 20  1601881800 1.17282 1.17285 1.17280 1.17280           53       1
# 21  1601881860 1.17279 1.17280 1.17275 1.17278           28       1
# 22  1601881920 1.17277 1.17280 1.17275 1.17280           35       1
# 23  1601881980 1.17279 1.17285 1.17273 1.17284           32       1
# 24  1601882040 1.17284 1.17290 1.17284 1.17289           17       1
# 25  1601882100 1.17287 1.17289 1.17282 1.17283           21       1
# 26  1601882160 1.17282 1.17285 1.17281 1.17283           18       1
# 27  1601882220 1.17282 1.17283 1.17276 1.17278           35       1
# 28  1601882280 1.17279 1.17291 1.17278 1.17290           22       1
# 29  1601882340 1.17291 1.17294 1.17288 1.17294           15       1
# 30  1601882400 1.17295 1.17296 1.17288 1.17289           32       1
# 31  1601882460 1.17290 1.17293 1.17289 1.17292           21       1
# 32  1601882520 1.17291 1.17297 1.17291 1.17291           24       1
# 33  1601882580 1.17292 1.17300 1.17291 1.17296           32       1
# 34  1601882640 1.17295 1.17296 1.17289 1.17290           25       1
# 35  1601882700 1.17291 1.17304 1.17290 1.17301           21       1
# 36  1601882760 1.17301 1.17304 1.17299 1.17303           37       1
# 37  1601882820 1.17303 1.17305 1.17299 1.17303           28       1
# 38  1601882880 1.17302 1.17306 1.17302 1.17305           14       1
# 39  1601882940 1.17305 1.17305 1.17303 1.17304           30       1
# 40  1601883000 1.17306 1.17314 1.17300 1.17310           62       1
# 41  1601883060 1.17309 1.17321 1.17306 1.17316           47       1
# 42  1601883120 1.17316 1.17321 1.17315 1.17321           37       1
# 43  1601883180 1.17320 1.17325 1.17320 1.17324           35       1
# 44  1601883240 1.17321 1.17325 1.17321 1.17322           23       1
# 45  1601883300 1.17321 1.17321 1.17316 1.17320           27       1
# 46  1601883360 1.17321 1.17324 1.17320 1.17321           12       1
# 47  1601883420 1.17320 1.17324 1.17320 1.17321            8       1
# 48  1601883480 1.17322 1.17325 1.17319 1.17325           21       1
# 49  1601883540 1.17325 1.17326 1.17324 1.17325           22       0
#
#     real_volume
# 0       9500000
# 1       6700000
# 2      23700000
# 3      36400000
# 4      14290000
# 5      32850000
# 6       4800000
# 7      33780000
# 8      19400000
# 9       9200000
# 10     17582000
# 11      7700000
# 12      5000000
# 13     52200000
# 14     11300000
# 15     60190000
# 16    102299000
# 17     33000000
# 18      6400000
# 19     70550000
# 20    181600000
# 21     40300000
# 22     79000000
# 23     54050000
# 24     13650000
# 25      2600000
# 26      4800000
# 27     12900000
# 28      9700000
# 29     13000000
# 30     25950000
# 31      2100000
# 32     12400000
# 33      8200000
# 34      2500000
# 35     19600000
# 36     55200000
# 37     56300000
# 38     36300000
# 39     17000000
# 40     55750000
# 41     97800000
# 42     52600000
# 43     49500000
# 44     23300000
# 45     19700000
# 46      1200000
# 47      1700000
# 48      7600000
# 49     17100000

# %%
# print('Importing and set up time = %0.4f' % (time.time() - startTime))

def getData(numBefore, timePeriod, signal):
    # Match the mt5 trading time zone (UMT+3)
    timezone = pytz.timezone("Etc/GMT+3")    
    
    endDate = dt.now(timezone) # The most recent time
    timeBefore = (int(timePeriod) * numBefore)*60 # In seconds
    
    delta = datetime.timedelta(seconds=timeBefore)
    startDate = endDate - delta
    
    rates = mt5.copy_rates_range(signal, timePeriod, startDate, endDate)
    ratesDf = pd.DataFrame(rates)
    return ratesDf

# Give closePrices as an array
def getBollBands(closePrices, period=20, numStd=2):
    # Default values for bollinger bands = 20 for period & 2 for std
    bands = {k:[] for k in ['topBand','bottomBand', 'mav']} # Set lists as defaults

    for i in range(1, len(closePrices)+1):
        if i < period:
            currDat = closePrices[0:i]
        else:
            currDat = closePrices[i-period:i]

        std = np.std(currDat)
        mean = np.mean(currDat)

        bands['topBand'].append(mean+numStd*std)
        bands['bottomBand'].append(mean-numStd*std)
        bands['mav'].append(mean)

    # Remove the first n (period) of values as they are not accurate/just used for calculation
    for key, val in bands.items():
        tempVal = val.copy()
        tempVal[:period] = [float('nan')]*period
        bands[key] = tempVal

    bollDf = pd.DataFrame.from_dict(bands)
    return bollDf

@nb.jit(fastmath=True, nopython=True)   
def calc_rsi( array, deltas, avg_gain, avg_loss, n ):

# Use Wilder smoothing method
    up   = lambda x:  x if x > 0 else 0
    down = lambda x: -x if x < 0 else 0
    i = n+1
    for d in deltas[n+1:]:
        avg_gain = ((avg_gain * (n-1)) + up(d)) / n
        avg_loss = ((avg_loss * (n-1)) + down(d)) / n
        if avg_loss != 0:
            rs = avg_gain / avg_loss
            array[i] = 100 - (100 / (1 + rs))
        else:
            array[i] = 100
        i += 1

    return array

# Default period for the RSI indicator is 14
def getRSI(array, n = 14):   

    deltas = np.append([0],np.diff(array))

    avg_gain =  np.sum(deltas[1:n+1].clip(min=0)) / n
    avg_loss = -np.sum(deltas[1:n+1].clip(max=0)) / n

    array = np.empty(deltas.shape[0])
    array.fill(np.nan)

    array = calc_rsi( array, deltas, avg_gain, avg_loss, n )
    return array

def getMostRecent(rsi, boll, rates):   
    times = rates['time'].values
    
    # First get the RSI, signal and Bollinger bands in a dataframe with respect to time
    algDf = pd.DataFrame()
    algDf['Date'] = times
    algDf = algDf.set_index('Date')

    # Add the RSI values
    algDf['RSI'] = list(rsi)

    # Add the signal values (using the close value)
    algDf['Signal'] = rates['close'].values

    # Add the bollinger bands (can use the mav to figure out the take-profit value)
    boll.reset_index(inplace=True)
    boll['Date'] = times
    boll = boll.set_index('Date')
    
    concatDf = pd.concat([algDf, boll], axis=1)
    
    # Just get the array where the most recent time stamp is
    recentTime = max(concatDf.index)
    recentDf = concatDf[concatDf.index==recentTime]

    return recentDf, recentTime

def checkMakeTrade(recentDf, threshUp=70, threshDown=30) :
    # Thresholds for the RSI being a snapback
    recDict = recentDf.to_dict(orient='list')

    makeTrade = False
    # Case 1 - signal is above topBand and RSI is > upperthresh
    if (recDict['Signal'] > recDict['topBand']) and (recDict['RSI'] > threshUp):
        makeTrade = True
    elif (recDict['Signal'] < recDict['bottomBand'] and (recDict['RSI'] < threshDown)):
        makeTrade = True

    return makeTrade





################################################################
######## MAIN CODE OVER HERE:
################################################################

def popupmsg(msg):
    FONT = ("Verdana", 48)
    popup = tk.Tk()
    popup.wm_title("!")
    label = ttk.Label(popup, text=msg, font=FONT)
    label.pack(side="top", fill="x", pady=30, padx=30)
    B1 = ttk.Button(popup, text="Okay", command = popup.destroy)
    B1.pack()
    popup.mainloop()

def sendEmail(msg):
    context = ssl.create_default_context()
    with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, msg)

def checkAllSigs(numBefore, timePeriod, signals, verbose=False):
    maxTime = None
    recVals = None

    for currSig in signals:
        makeTrade = False
        try:
            rates = getData(numBefore, timePeriod, currSig.name)
            boll = getBollBands(rates.close)
            rsi = getRSI(rates.close)
            recVals, maxTime = getMostRecent(rsi, boll, rates)
            makeTrade = checkMakeTrade(recVals)

            if verbose: print(f'For signal {currSig.name}, make trade = {makeTrade}')
        except Exception as e:
            if verbose: print(f'FAILED FOR {currSig.name}. {e}')

        # If there's a signal which should be traded, open a window
        if makeTrade:
            popupmsg(f'Make a trade on signal {currSig.name}')
            sendEmail(f'Subject: Make a trade on signal {currSig.name}\n\nHi there,\n\nCoding bot has found a suitable trade\n\nThanks')

    return maxTime

# %%
## Initialise the MT5 trading portal
initTime = time.time()

if not mt5.initialize():
	print(mt5.last_error())
	mt5.shutdown()
else:
	authorized=mt5.login(62986, password="xo7rslrx")
	print('\nInitialised mt5 successfully! Took %0.3f seconds...\n' % (time.time() - initTime))

# Uncomment below if you want to see your account info

# account_info=mt5.account_info()
# print(account_info)

# Set up the time period (IMPORTANT)
timeDict = {'15': mt5.TIMEFRAME_M15, '30': mt5.TIMEFRAME_M30, '60': mt5.TIMEFRAME_H1}
timePeriod = '15'

# Get the data for n periods prior to the current period
numBefore = 40 # number of periods prior to the current one
signals = mt5.symbols_get(group="*USD*,*EUR*,*JPY*,*GBP*,*AUD*,!*USDOLLAR*,!*TRY*")

# Set up the credentials for sending mail
port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "rgforexbot@gmail.com"  # Enter your address
receiver_email = "rudyg.ace@gmail.com"  # Enter receiver address
password = 'bigbucks123'
# Out:
# Initialised mt5 successfully! Took 0.011 seconds...

# %%
### WANT TO DO THE NEXT CODE EVERY TIME PERIOD (i.e. WHENEVER THERE IS MORE DATA)

# Do the checks once to initialise then run in a loop
prevMaxTime = checkAllSigs(numBefore, timeDict[timePeriod], signals, verbose=True)
newCollectTime = prevMaxTime + datetime.timedelta(seconds=int(timePeriod)*60).total_seconds()
# Out:
# For signal EURUSD, make trade = False
# For signal GBPUSD, make trade = False
# For signal USDCHF, make trade = False
# For signal USDJPY, make trade = False
# For signal USDCAD, make trade = False
# For signal AUDUSD, make trade = False
# For signal AUDNZD, make trade = False
# For signal AUDCAD, make trade = False
# For signal AUDCHF, make trade = False
# For signal AUDJPY, make trade = False
# For signal CHFJPY, make trade = False
# For signal EURGBP, make trade = False
# For signal EURAUD, make trade = False
# For signal EURCHF, make trade = False
# For signal EURJPY, make trade = False
# For signal EURNZD, make trade = False
# For signal EURCAD, make trade = False
# For signal GBPCHF, make trade = False
# For signal GBPJPY, make trade = False
# For signal AUDHKD, make trade = False
# For signal EURDKK, make trade = False
# For signal EURHUF, make trade = False
# For signal EURMXN, make trade = False
# For signal EURNOK, make trade = False
# For signal EURPLN, make trade = False
# For signal EURSEK, make trade = False
# For signal USDCNH, make trade = False
# For signal USDDKK, make trade = False
# For signal USDHKD, make trade = False
# For signal USDHUF, make trade = False
# For signal USDMXN, make trade = False
# For signal USDNOK, make trade = False
# For signal USDPLN, make trade = False
# For signal USDSEK, make trade = False
# For signal USDZAR, make trade = False
# For signal CADJPY, make trade = False
# For signal GBPAUD, make trade = False
# For signal GBPCAD, make trade = False
# For signal GBPNZD, make trade = False
# For signal NZDJPY, make trade = False
# For signal NZDUSD, make trade = False
# For signal USDSGD, make trade = False
# For signal UKOUSD, make trade = False
# For signal USOUSD, make trade = False
# For signal XAGUSD, make trade = False
# For signal XAUUSD, make trade = False
# For signal BCHUSD, make trade = False
# For signal BTCUSD, make trade = False
# For signal ETHUSD, make trade = False
# For signal LTCUSD, make trade = False
# For signal XRPUSD, make trade = False

# %%
timezone = pytz.timezone("Etc/GMT+3")    

while(True):
    currTimeAdjusted = (dt.now(timezone) - dt(1970,1,1, tzinfo=timezone)).total_seconds() 
    if currTimeAdjusted > newCollectTime: # A new piece of data has arrived # Use 7 hours as the time zone of GoMarkets is 7 hours behind
        print('Collecting new data!')
        prevMaxTime = checkAllSigs(numBefore, timePeriod, signals, verbose=True)
        newCollectTime = prevMaxTime + datetime.timedelta(seconds=int(timePeriod)*60).total_seconds()

    else:
        time.sleep(3)
        print('Waiting for new data...')
# Out:
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# Waiting for new data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-7ca76dced74e> in <module>
#       9
#      10     else:
# ---> 11         time.sleep(3)
#      12         print('Waiting for new data...')
#
# KeyboardInterrupt:
